# %%
from pydantic import BaseModel, EmailStr, ValidationError

# %%
class UserInput(BaseModel):
    name:str
    email:EmailStr
    query:str

# %%
user_input = UserInput(name= "Waqas", email="waqas@gmail.com", query="I forget my password")

# %%
user_input
# Out:
# UserInput(name='Waqas', email='waqas@gmail.com', query='I forget my password')

# %%
print(user_input.model_dump_json(indent = 2))
# Out:
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password"
# }

# %%
user_input = UserInput(name= "Waqas", email="waqas@gmail.com", query="I forget my password")

# %%
def validate_user_input(input_data):
    try:
        user_input = UserInput(**input_data)
        print("Valid Input data is created")
        print(user_input.model_dump_json(indent=2))
        return user_input
    except ValidationError as e:
        print("Validation error occurred")
        for error in e.errors():
            print(f"{error["loc"][0]}:{error["msg"]}")
        return None

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password"
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password"
# }

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
}

user_input = validate_user_input(input_data)
# Out:
# Validation error occurred
# query:Field required

# %%
input_data = {
  "name": "Waqas",
  "email": "waqasgmail.com",
  "query": "I forget my password"
}

user_input = validate_user_input(input_data)
# Out:
# Validation error occurred
# email:value is not a valid email address: An email address must have an @-sign.

# %%
input_data = {
  "name": 12345,
  "email": "waqasgmail.com",
  
}

user_input = validate_user_input(input_data)
# Out:
# Validation error occurred
# name:Input should be a valid string
# email:value is not a valid email address: An email address must have an @-sign.
# query:Field required

# %%
from typing import Optional
from pydantic import Field
from datetime import date

# %%
class UserInput(BaseModel):
    name:str
    email:EmailStr
    query:str
    order_id:Optional[int] = Field(None,
                                   description="5 Digit order number (can not start with 0)",
                                   ge= 10000,le = 99999)
    purchase_date:Optional[date] = None

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password"
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": null,
#   "purchase_date": null
# }

# %%
user_input
# Out:
# UserInput(name='Waqas', email='waqas@gmail.com', query='I forget my password', order_id=None, purchase_date=None)

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": None,
  "purchase_date": None
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": null,
#   "purchase_date": null
# }

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": 12345,
  "purchase_date": None
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": 12345,
#   "purchase_date": null
# }

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": 12345,
  "purchase_date": date(2015,12,31)
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": 12345,
#   "purchase_date": "2015-12-31"
# }

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": 12345,
  "purchase_date": "2015-12-31"
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": 12345,
#   "purchase_date": "2015-12-31"
# }

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": 12345,
  "purchase_date": "31/12/2025"
}

user_input = validate_user_input(input_data)
# Out:
# Validation error occurred
# purchase_date:Input should be a valid date or datetime, invalid character in year

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": "12345",
  "purchase_date": "2025-12-31"
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": 12345,
#   "purchase_date": "2025-12-31"
# }

# %%
input_data = {
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": "12345",
  "purchase_date": "2025-12-31",
    "System_message":"NED session is on",
    "location": "CCEE"
}

user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": 12345,
#   "purchase_date": "2025-12-31"
# }

# %%
json_data = """{
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": "12345",
  "purchase_date": "2025-12-31",
    "System_message":"NED session is on",
    "location": "CCEE"
}"""

user_input = validate_user_input(json_data)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[158], line 11
#       1 json_data = """{
#       2   "name": "Waqas",
#       3   "email": "waqas@gmail.com",
#    (...)      8     "location": "CCEE"
#       9 }"""
# ---> 11 user_input = validate_user_input(json_data)
#
# Cell In[133], line 3, in validate_user_input(input_data)
#       1 def validate_user_input(input_data):
#       2     try:
# ----> 3         user_input = UserInput(**input_data)
#       4         print("Valid Input data is created")
#       5         print(user_input.model_dump_json(indent=2))
#
# TypeError: __main__.UserInput() argument after ** must be a mapping, not str

# %%
import json

json_data = """{
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": "12345",
  "purchase_date": "2025-12-31",
    "System_message":"NED session is on",
    "location": "CCEE"
}"""

input_data = json.loads(json_data)
user_input = validate_user_input(input_data)
# Out:
# Valid Input data is created
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": 12345,
#   "purchase_date": "2025-12-31"
# }

# %%
json_data = """{
  "name": "Waqas",
  "email": "waqas@gmail.com",
  "query": "I forget my password",
  "order_id": "12345",
  "purchase_date": "2025-12-31",
    "System_message":"NED session is on",
    "location": "CCEE"
}"""

user_input = UserInput.model_validate_json(json_data)

# %%
print(user_input.model_dump_json(indent = 2))
# Out:
# {
#   "name": "Waqas",
#   "email": "waqas@gmail.com",
#   "query": "I forget my password",
#   "order_id": 12345,
#   "purchase_date": "2025-12-31"
# }
